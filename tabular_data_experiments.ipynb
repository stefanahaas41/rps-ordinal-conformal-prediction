# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from util.tabular_experiments_runner import run_experiment


datasets = {
    #"winequalityRed": "TOC-UCO/data/oc05_winequalityRed.csv",
    # "LESTSensors": "TOC-UCO/data/oc04_LESTSensors.csv",
    # "LEVXSensors": "TOC-UCO/data/oc04_LEVXSensors.csv",
    # "swd": "TOC-UCO/data/oc04_swd.csv",
     "nhanes": "TOC-UCO/data/oc05_nhanes.csv",
    # "melbourneAirbnb": "TOC-UCO/data/oc10_melbourneAirbnb.csv",
    # "cancerDeathRate": "TOC-UCO/data/dr10_cancerDeathRate.csv",
    # "insurance": "TOC-UCO/data/dr09_insurance.csv",
    # "era": "TOC-UCO/data/oc09_era.csv",
    # "lev": "TOC-UCO/data/oc05_lev.csv"
}


for dataset, path in datasets.items():
    X = pd.read_csv(path, header=0)
    y = X.pop('y')
    le = LabelEncoder()
    le.fit(y)
    run_experiment(X, y, le, dataset)
# Out:
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.5257       0.2887        1.4853  0.0313
#       2        1.4546       0.3541        1.4339  0.0316
#       3        1.4036       0.3844        1.3968  0.0313
#       4        1.3679       0.3923        1.3710  0.0313
#       5        1.3426       0.4179        1.3552  0.0366
#       6        1.3226       0.4211        1.3425  0.0313
#       7        1.3084       0.4211        1.3345  0.0605
#       8        1.2975       0.4179        1.3279  0.0314
#       9        1.2881       0.4242        1.3267  0.0313
#      10        1.2820       0.4179        1.3259  0.0263
#      11        1.2773       0.4274        1.3216  0.0317
#      12        1.2724       0.4163        1.3242  0.0316
#      13        1.2676       0.4195        1.3228  0.0470
#      14        1.2648       0.4131        1.3255  0.0313
#      15        1.2600       0.4163        1.3238  0.0316
#      16        1.2561       0.4147        1.3251  0.0313
#      17        1.2542       0.4051        1.3271  0.0314
#      18        1.2505       0.4147        1.3255  0.0479
#      19        1.2477       0.4083        1.3288  0.0211
#      20        1.2446       0.4115        1.3307  0.0538
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.5947       0.3573        1.5268  0.0324
#       2        1.4770       0.4035        1.4465  0.0470
#       3        1.4030       0.4035        1.4018  0.0480
#       4        1.3608       0.4003        1.3785  0.0557
#       5        1.3354       0.4067        1.3648  0.0317
#       6        1.3187       0.4131        1.3569  0.0313
#       7        1.3074       0.4163        1.3524  0.0478
#       8        1.2980       0.4242        1.3479  0.0465
#       9        1.2907       0.4226        1.3443  0.0370
#      10        1.2841       0.4226        1.3416  0.0418
#      11        1.2784       0.4274        1.3396  0.0604
#      12        1.2733       0.4274        1.3390  0.0576
#      13        1.2691       0.4211        1.3389  0.0360
#      14        1.2650       0.4226        1.3378  0.0302
#      15        1.2611       0.4258        1.3373  0.0473
#      16        1.2578       0.4274        1.3356  0.0316
#      17        1.2543       0.4274        1.3361  0.0307
#      18        1.2516       0.4274        1.3358  0.0329
#      19        1.2485       0.4274        1.3367  0.0312
#      20        1.2460       0.4258        1.3373  0.0312
